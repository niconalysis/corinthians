# %%
ficha = """
Ficha técnica de Palmeiras 0 x 1 Corinthians
Competição: Campeonato Paulista
Local: Allianz Parque, São Paulo, SP
Data: 16 de março de 2025 (domingo)
Horário: 18h30 (de Brasília)
Árbitro: Raphael Claus
Assistentes: Alex Ang Ribeiro e Fabrini Bevilaqua Costa
Árbitro de vídeo: José Claudio Rocha Filho
Gol: Yuri Alberto (Corinthians)
Cartões amarelos: Martínez e Abel Ferreira (Palmeiras); Fabrizio Angileri e Talles Magno (Corinthians)
Público: 40.992 pagantes (público total: 40.992)
Renda: R$ 5.717.077,40

PALMEIRAS: Weverton; Marcos Rocha (Mayke), Murilo, Micael e Piquerez; Richard Ríos (Flaco López), Martínez (Aníbal Moreno) e Raphael Veiga; Facundo Torres (Felipe Anderson), Estêvão e Vitor Roque.
Técnico: Abel Ferreira

CORINTHIANS: Hugo Souza; Matheuzinho, Félix Torres, Gustavo Henrique e Fabrizio Angileri; Raniele (Alex Santana), José Martínez (Ryan), André Carrillo (Breno Bidon) e Romero (Talles Magno); Memphis Depay e Yuri Alberto (Charles).
Técnico: Ramón Díaz"""

jogo = 19

ficha = ficha.split('\n')

# %%
#puxar a data
meses = {
    "janeiro": "01",
    "fevereiro": "02",
    "março": "03",
    "abril": "04",
    "maio": "05",
    "junho": "06",
    "julho": "07",
    "agosto": "08",
    "setembro": "09",
    "outubro": "10",
    "novembro": "11",
    "dezembro": "12"
}



for linha in ficha:
    if 'Data: ' in linha:
        linha = linha.split(' ')
        dia = linha[1]
        mes = linha[3]
        ano = linha[-2]
        
data = (f"{dia}/{meses[mes]}/{ano}")
print(data)
# Out:
# 16/03/2025

# %%
for linha in ficha:
    if 'Local: Neo Química Arena, São Paulo, SP' in ficha:
        if 'Ficha técnica de ' in linha:
           linha = linha.split(' ')
           print(linha[4])
           gol_cor = linha[4]          
           print(linha[6])
           gol_adv = linha[6]
    else:
        if 'Ficha técnica de ' in linha:
            linha = linha.split(' ')
            print(linha[-2])
            gol_cor = linha[-2]
            print(linha[-4])
            gol_adv = linha[-4]
# Out:
# 1
# 0

# %%
import re

mapeamento_adv = {"Guarani":1,
"Ituano":2,
"São Bernardo FC":3,
"São Paulo":4,
"Novorizontino":5,
"Santos":6,
"Portuguesa":7,
"Botafogo-SP":8,
"Palmeiras":9,
"Cianorte":10,
"Ponte Preta":11,
"Santo André":12,
"Água Santa":13,
"Londrina":14,
"Racing-URU":15,
"Nacional-PAR":16,
"Atlético-MG":17,
"Juventude":18,
"Red Bull Bragantino":19,
"Argentinos Juniors":20,
"Fluminense":21,
"América-RN":22,
"Fortaleza":23,
"Flamengo":24,
"Botafogo":25,
"Atlético-GO":26,
"Internacional":27,
"Athletico-PR":28,
"Cuiabá":29,
"Vitória":30,
"Cruzeiro":31,
"Vasco da Gama":32,
"Criciúma":33,
"Bahia":34,
"Grêmio":35,
"Racing Club":36,
"Velo Clube":37,
"Noroeste":38,
"Inter de Limeira":39,
"Mirassol":40,
"Liverpool":41,
"Remo":42,
"Goiás":43,
"Independiente Del Valle":44,
"América-MG":45,
"Universitario de Deportes":46,
"Newells Old Boys":47,
"Coritiba":48,
"Estudiantes":49,
"Universidad Central":50,
"Ferroviária":51,
"Always Ready":52,
"Deportivo Cali":53,
"Avaí":54,
"Portuguesa-RJ":55,
"Boca Juniors":56,
"Ceará":57,
"New York City FC":58,
"Atlético Nacional":59,
"Guaraní-PY":60,
"Oeste":61,
"Sport":62,
"São Caetano":63,
"Salgueiro":64,
"Retrô FC":65,
"São Bento":66,
"River Plate-PAR":67,
"Peñarol":68,
"Sport Huancayo":69,
"Chapecoense":70,
"Barcelona de Guayaquil":71,
}

for linha in ficha:
    if 'Local: Neo Química Arena, São Paulo, SP' in ficha:
        if 'Ficha técnica de ' in linha:
            linha = linha.split(' ')
            adversario = linha[7:]
            adversario_formatado = ' '.join(adversario)
    else:
        if 'Ficha técnica de ' in linha:
            busca = re.search(r'Ficha técnica de (.*?) \d x \d',linha)
            if busca:
                adversario_formatado = busca.group(1)

if adversario_formatado in mapeamento_adv.keys():
    id_adversario = mapeamento_adv[adversario_formatado]
else:
    print('cadastrar adversario')
    id_adversario = list(mapeamento_adv.values())[-1] + 1 
    print(f'"{adversario_formatado}":{id_adversario},')
    print(f"({id_adversario},'{adversario_formatado}','Estado','País')")

# %%
mapeamento_tec_adv = {
    "Abel Ferreira":1,
"António Oliveira":2,
"Artur Jorge":3,
"Bernardo Franco":4,
"Brigatti":5,
"Bruno Pivetti":6,
"Cláudio Tencati":7,
"Cuca":8,
"Eduardo Baptista":9,
"Eduardo Coudet":10,
"Eduardo Espinel":11,
"Emerson Ávila":12,
"Fábio Carille":13,
"Fernando Diniz":14,
"Fernando Seabra":15,
"Filipe Luís":16,
"Gabriel Milito":17,
"Gustavo Costas":18,
"Jair Ventura":19,
"Juan Pablo Vojvoda":20,
"Lucho González":21,
"Luis Zubeldía":22,
"Mano Menezes":23,
"Márcio Fernandes":24,
"Márcio Zanardi":25,
"Marquinhos Santos":26,
"Pablo Guede":27,
"Paulo Gomes":28,
"Pedro Caixinha":29,
"Petit":30,
"Pintado":31,
"Rafael Paiva":32,
"Ramón Díaz":33,
"Raphael Laruccia":34,
"Renato Portaluppi":35,
"Roger Machado":36,
"Rogério Ceni":37,
"Thiago Carpini":38,
"Tite":39,
"Umberto Louzer":40,
"Víctor Bernay":41,
"Zé Roberto":42,
"Márcio Freitas":43,
"Guilherme Alves":44,
"Marcelo Cabo":45,
"Alberto Valentim":46,
"Paulo Sérgio Comelli":47,
"Ricardo Catalá":48,
"Cauan de Almeida":49,
"Mozart":50,
"Paulo Baier":51,
"Gilson Kleina":52,
"Odair Hellmann":53,
"Matheus Costa":54,
"Gilmar Dal Pozzo":55,
"Jorge Brava":56,
"Pepa":57,
"Emerson Avila":58,
"Martin Anselmi":59,
"Luís Castro":60,
"Dorival Júnior":61,
"Jorge Sampaoli":62,
"Eduardo Barros":63,
"Vagner Mancini":64,
"Wesley Carvalho":65,
"Luiz Felipe Scolari":66,
"Jorge Fossati":67,
"Renato Paiva":68,
"Ramón Diaz":69,
"Gabriel Heinze":70,
"Thiago Kosloski":71,
"Eduardo Rodrigo Dominguez":72,
"Armando Evangelista":73,
"Bruno Lage":74,
"Mario Jorge":75,
"Fabián Bustos":76,
"Marcelo Fernandes":77,
"Guto Ferreira":78,
"Daniel Sasso":79,
"Elano Blumer":80,
"Mazola":81,
"Leandro Zago":82,
"Maurício Barbieri":83,
"Hélio dos Anjos":84,
"Allan Aal":85,
"Daniel Paulista":86,
"Eduardo Villegas":87,
"Rafael Dudamel":88,
"Eduardo Barroca":89,
"Toninho Andrade":90,
"Sebastian Battaglia":91,
"Felipe Surian":92,
"Sebastián Battaglia":93,
"Jorginho":94,
"Gustavo Moringo":95,
"Lucas Gonçalves":96,
"Lucas Zanella":97,
"Orlando Ribeiro":98,
"Juca Antonello":99,
"Ronny Deila":100,
"Pompilio Páez":101,
"Wagner Lopes":102,
"Jesualdo Ferreira":103,
"Paulo Roberto Santos":104,
"Roberto Fonseca":105,
"Vinícius Bergantin":106,
"Vanderlei Luxemburgo":107,
"Renan Freitas":108,
"Felipe Conceição":109,
"Thiago Larghi":110,
"Paulo Autuori":111,
"Domènec Torrent":112,
"Ricardo Sá Pinto":113,
"Lisca Doido":114,
"Eduardo Souza":115,
"Rodrigo Santana":116,
"Marcelo Chamusca":117,
"Glauber Ramos":118,
"Maurício Souza":119,
"Ivan Baitello":120,
"Marcão":121,
"Dado Cavalcanti":122,
"Abel Braga":123,
"Fábio Moreno":124,
"Wilson Júnior":125,
"Daniel Neri":126,
"Nilson Corrêa":127,
"Edson Vieira":128,
"Vinicius Bergantin":129,
"Celso Ayala":130,
"Ariel Holan":131,
"Mauricio Larriera":132,
"Hernán Crespo":133,
"Wilmar Valencia Pacheco":134,
"Léo Condé":135,
"Diego Aguirre":136,
"Diego Dabove":137,
"Gustavo Florentín":138,
"Felipe Endres":139,
"Tiago Nunes":140,
"Segundo Castillo":141,
}

# %%
mapeamento_tec_cor = {
"António Oliveira":1,
"Mano Menezes":2,
"Ramón Díaz":3,
"Raphael Laruccia":4,
"Thiago Kosloski":5,
"Fernando Lázaro":6,
"Cuca":7,
"Danilo":8,
"Vanderlei Luxemburgo":9,
"Sylvinho":10,
"Vítor Pereira":11,
"Tiago Nunes":12,
"Dyego Coelho":13,
"Vagner Mancini":14,
}



for linha in ficha:
    if 'Local: Neo Química Arena, São Paulo, SP' in ficha:
        tecnico_adv = ficha[-1].replace('Técnico: ','')
        tecnico_cor = ficha[-4].replace('Técnico: ','')
    else:
        tecnico_adv = ficha[-4].replace('Técnico: ','')
        tecnico_cor = ficha[-1].replace('Técnico: ','')

if tecnico_cor in mapeamento_tec_cor.keys():
    id_tecnico_cor = mapeamento_tec_cor[tecnico_cor]
elif tecnico_cor == 'Filipe Almeida':
    id_tecnico_cor = mapeamento_tec_cor['Vítor Pereira']
else:
    print('cadastrar tecnico corinthians')
    id_tecnico_cor = list(mapeamento_tec_cor.values())[-1] + 1 
    print(f"({id_tecnico_cor},'{tecnico_cor}','DataNasc','Cidade','Estado','País','Imagem')")

if tecnico_adv in mapeamento_tec_adv.keys():
    id_tecnico_adv = mapeamento_tec_adv[tecnico_adv]
elif tecnico_adv == 'Martín Anselmi':
    id_tecnico_adv = mapeamento_tec_adv['Martin Anselmi']
elif tecnico_adv == 'Odair Hellman':
    id_tecnico_adv = mapeamento_tec_adv['Odair Hellmann']
elif tecnico_adv == 'Luis Castro':
    id_tecnico_adv = mapeamento_tec_adv['Luís Castro']
elif tecnico_adv == 'Jorge Rodrigo Bava':
    id_tecnico_adv = mapeamento_tec_adv['Jorge Brava']
elif tecnico_adv == 'Eduardo Domínguez':
    id_tecnico_adv = mapeamento_tec_adv['Eduardo Rodrigo Dominguez']
elif tecnico_adv == 'Renato Gaúcho':
    id_tecnico_adv = mapeamento_tec_adv['Renato Portaluppi']
elif tecnico_adv == 'W. Valencia':
    id_tecnico_adv = mapeamento_tec_adv['Wilmar Valencia Pacheco']
elif tecnico_adv == 'Felipão':
    id_tecnico_adv = mapeamento_tec_adv['Luiz Felipe Scolari']
else:
    print('cadastrar tecnico adversario')
    id_tecnico_adv = list(mapeamento_tec_adv.values())[-1] + 1 
    print(f'"{tecnico_adv}":{id_tecnico_adv},')
    id_tecnico_adv = list(mapeamento_tec_adv.values())[-1] + 1 
    print(f"({id_tecnico_adv},'{tecnico_adv}','','Cidade','Estado','País','Imagem')")

# %%
mapeamento_campeonatos = {
    "Campeonato Brasileiro":1,
"Copa do Brasil":2,
"Campeonato Paulista":3,
"Copa Sulamericana":4,
"Copa Libertadores da América":5,
"Amistoso":6,
"Mundial":7,
"Florida Cup":8,
}

for linha in ficha:
    if 'Competição: ' in linha:
        campeonato = linha.replace('Competição: ','')

if campeonato in mapeamento_campeonatos.keys():
    id_campeonato = (mapeamento_campeonatos[campeonato])
elif campeonato == 'Copa Sul-Americana':
    id_campeonato = (mapeamento_campeonatos['Copa Sulamericana'])
elif campeonato == 'Copa Conmebol Libertadores da América':
    id_campeonato = (mapeamento_campeonatos['Copa Libertadores da América'])   
elif campeonato == 'Campeonato Paulista Sicredi 2022':
    id_campeonato = (mapeamento_campeonatos['Campeonato Paulista'])
elif campeonato == 'Campeonato Paulista Sicredi':
    id_campeonato = (mapeamento_campeonatos['Campeonato Paulista'])    
else:
    print('cadastrar campeonato novo')
    id_campeonato = list(mapeamento_campeonatos.values())[-1] + 1
    print(f"({id_campeonato},'{campeonato}')")

# %%
mapeamento_arbitros = {
    "Thiago Luis Scarascati":1,
"Matheus Delgado Candançan":2,
"João Vitor Gobi":3,
"Vinícius Gonçalves Dias Araújo":4,
"Flávio Rodrigues de Souza":5,
"Luiz Flávio de Oliveira":6,
"Fabiano Monteiro dos Santos":7,
"Raphael Claus":8,
"Paulo Cesar Zanovelli da Silva":9,
"Braulio da Silva Machado":10,
"André Ricardo Martins":11,
"Jhon Hinestroza":12,
"Jhon Ospina":13,
"Yuri Elino Ferreira da Cruz":14,
"Bruno Arleu de Araújo":15,
"Rafael Rodrigo Klein":16,
"Piero Maza":17,
"Ramon Abatti Abel":18,
"Maguielson Lima Barbosa":19,
"Felipe Fernandes de Lima":20,
"Ángel Arteaga Cabriales":21,
"Felipe González Alveal":22,
"Lucas Paulo Torezin":23,
"Roberto Pérez Gutierrez":24,
"Anderson Daronco":25,
"Wagner do Nascimento Magalhães":26,
"Fabio Augusto Sá Júnior":27,
"Gustavo Ervino Bauermann":28,
"Alex Gomes Stefano":29,
"Jonathan Benkenstein Pinheiro":30,
"Marcelo de Lima Henrique":31,
"Andrés Rojas":32,
"Dario Herrera":33,
"Wilton Pereira Sampaio":34,
"Gustavo Tejera":35,
"Davi de Oliveira Lacerda":36,
"Lucas Canetto Bellote":37,
"Edina Alves Batista":38,
"Daiane Caroline Muniz dos Santos":39,
"Douglas Marques das Flores":40,
"Guilherme Nunes de Santana":41,
"Jesús Noel Valenzuela Sáez":42,
"Carlos Ortega":43,
"Leandro Pedro Vuaden":44,
"Alexis Herrera":45,
"André Luis Skettino Policarpo Bento":46,
"Rodrigo José Pereira de Lima":47,
"Wilmar Roldán":48,
"Esteban Ostojich":49,
"André Luiz Skettino Policarpo Bento":50,
"Savio Pereira Sampaio":51,
"Caio Max Augusto Vieira":52,
"Thiago Lourenço de Mattos":53,
"Eber Aquino Gaona":54,
"Paulo Roberto Alves Júnior":55,
"Andres Matonte":56,
"Andrés Cunha":57,
"Christian Ferreyra":58,
"José Ramón Argote Vega":59,
"Roberto Tobar":60,
"Jean Pierre Gonçalves Lima":61,
"Patrício Loustau":62,
"JJ Bilinski":63,
"Matthew Miscannon":64,
"Thiago Duarte Peixoto":65,
"Néstor Pitana":66,
"Salim Fende Chavez":67,
"Rodolpho Toski Marques":68,
"José Mendonça da Silva Junior":69,
"Rafael Traci":70,
"Rodrigo DAlonso Ferreira":71,
"Heber Roberto Lopes":72,
"Murilo Tarrega Victor":73,
"Ricardo Marques Ribeiro":74,
"Vinicius Gonçalves Dias Araújo":75,
"Facundo Tello":76,
"Angelo Hermosilla":77,
"José Argote":78,
"Antonio Dib Moraes de Sousa":79,
"Denis da Silva Ribeiro Serafim":80,
"Marielson Alves Silva":81,
}

for linha in ficha:
    if 'Árbitro: ' in linha:
        nome_arbitro = linha.replace('Árbitro: ','')

if nome_arbitro in mapeamento_arbitros.keys():
    id_arbitro = (mapeamento_arbitros[nome_arbitro])
elif nome_arbitro == 'Rodolpho Toski':
    id_arbitro = (mapeamento_arbitros['Rodolpho Toski Marques'])
else:
    print('cadastrar arbitro novo')
    id_arbitro = list(mapeamento_arbitros.values())[-1] + 1
    print(f'"{nome_arbitro}":{id_arbitro},')
    print(f"({id_arbitro},'{nome_arbitro}')")

# %%
mapeamento_estadios = {
    "Neo Química Arena":1,
"Municipal Doutor Novelli Júnior":2,
"Municipal Primeiro de Maio":3,
"Urbano Caldeira":4,
"Santa Cruz":5,
"Arena Barueri":6,
"Estádio Willie Davids":7,
"Estádio Olímpico Regional Arnaldo Busatto":8,
"Centenário":9,
"Alfredo Jaconi":10,
"Nabi Abi Chedid":11,
"Estádio Diego Armando Maradona":12,
"Arena das Dunas":13,
"Defensores del Chaco":14,
"Jornalista Mário Filho":15,
"Estádio Antônio Accioly":16,
"Orlando Scarpelli":17,
"Joaquim Américo Guimarães":18,
"Allianz Parque":19,
"Governador Magalhães Pinto":20,
"São Januário":21,
"Itaipava Arena Fonte Nova":22,
"Arena MRV":23,
"Major Antônio Couto Pereira":24,
"Governador Plácido Castelo":25,
"Nilton Santos":26,
"Mané Garrincha":27,
"Arena Pantanal":28,
"Estádio Presidente Juan Domingo Perón":29,
"Manoel Barradas":30,
"Heriberto Hülse":31,
"Arena do Grêmio":32,
"Cícero Pompeu de Toledo":33,
"Moisés Lucarelli":34,
"Municipal Paulo Machado de Carvalho":35,
"Major José Levy Sobrinho":36,
"Estádio Olímpico do Pará":37,
"Estádio Hailé Pinheiro":38,
"Estádio Raimundo Sampaio":39,
"Estádio Banco Guayaquil":40,
"Estadio Monumental U":41,
"José Pinheiro Borda":42,
"Estádio Marcelo Bielsa":43,
"Estádio Jorge Luis Hirshchi":44,
"Estadio Olímpico de la Universidad Central de Venezuela":45,
"Bruno José Daniel":46,
"Jorge Ismael de Biasi":47,
"Hernando Siles":48,
"Municipal Jacy Scaff":49,
"Deportivo Cali":50,
"Estádio Alberto Jacinto Armando":51,
"Aderbal Ramos da Silva":52,
"Exploria Stadium":53,
"Municipal José Maria de Campos Maia":54,
"La Nueva Olla":55,
"Distrital do Inamar":56,
"Governo do Estado de Goiás":57,
"Adelmar da Costa Carvalho":58,
"Estádio Olímpico Pedro Ludovico Teixeira":59,
"Anacleto Campanella":60,
"Estádio Municipal Cornélio de Barros Muniz e Sá":61,
"Estádio General Sylvio Raulino de Oliveira":62,
"Estádio Elcyr Resende de Mendonça":63,
"Brinco de Ouro da Princesa":64,
"Estádio Doutor Adhemar de Barros":65,
"Estádio Nacional do Peru":66,
"Campeón del Siglo":67,
"Roberto Santos":68,
"Arena Condá":69,
"Itaipava Arena Pernambuco":70,
"Estádio Monumental Isidro Romero Carbo":71,
}

for linha in ficha:
    if 'Local: ' in linha:
        if 'Brasil' in linha:
            linha = linha.replace('Local: ','')
            linha = linha.split(', ')
            estadio = linha[0]
            cidade = linha[1]
            estado = linha[2]
            pais = linha[3]
        else:
            linha = linha.replace('Local: ','')
            linha = linha.split(', ')
            estadio = linha[0]
            cidade = linha[1]
            pais = linha[2]


if estadio in mapeamento_estadios.keys():
    id_estadio = (mapeamento_estadios[estadio])
elif estadio == 'Arena Corinthians':
    id_estadio = (mapeamento_estadios['Neo Química Arena'])
elif estadio == 'Estadio Olímpico de la Universidad Central de Vene':
    id_estadio = (mapeamento_estadios["Estadio Olímpico de la Universidad Central de Venezuela"])
elif pais != 'Brasil':
    print('cadastrar nome estadio')
    id_estadio = list(mapeamento_estadios.values())[-1] + 1
    print(f'"{estadio}":{id_estadio},')
    print(f"({id_estadio},'{estadio}','{cidade}','','{pais}','','')")    
else:
    print('cadastrar nome estadio')
    id_estadio = list(mapeamento_estadios.values())[-1] + 1
    print(f'"{estadio}":{id_estadio},')
    print(f"({id_estadio},'{estadio}','{cidade}','{estado}','Brasil','','')")

# %%
for linha in ficha:
    if 'Renda: ' in linha:
        linha = linha.replace('Renda: R$ ','')
        linha = linha.replace('.','')
        linha = linha.replace(',','.')
        renda = linha
        print(renda)
        break
    else:
        renda = 0

for linha in ficha:
    if 'Público: ' in linha:
        linha = linha.replace('Público: ','')
        linha = linha.replace('.','')
        linha = linha.replace(',','.')
        linha = linha.replace(' torcedores','')
        publico = linha
        publico = publico.split(' ')
        publico = publico[0]
        print(publico)
        break
    else:
        publico = 0
# Out:
# 5717077.40
# 40992

# %%
print("INSERT INTO partidas_cor")
print("VALUES")
print(f"({jogo}{ano}, '{data}','Corinthians',{gol_cor},{id_adversario},{gol_adv},{id_tecnico_cor},{id_tecnico_adv},{id_campeonato},{id_arbitro},{id_estadio},{renda},{publico})")
# Out:
# INSERT INTO partidas_cor
# VALUES
# (192025, '16/03/2025','Corinthians',1,9,0,3,1,3,8,19,5717077.40,40992)
