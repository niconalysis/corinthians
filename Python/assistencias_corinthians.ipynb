# %%
jogadores = {
"Hugo Souza":1,
"Matheus Donelli":2,
"Cássio":3,
"Carlos Miguel":4,
"Felipe Longo":5,
"Félix Torres":6,
"André Ramalho":7,
"Raul Gustavo":8,
"Gustavo Henrique":9,
"Caetano":10,
"Cacá":11,
"Renato Santos":12,
"Tchoca":13,
"Diego Palacios":14,
"Matheus Bidu":15,
"Hugo":16,
"Vitor Meer":17,
"Fagner":19,
"Léo Maná":20,
"Matheuzinho":21,
"Fausto":22,
"José Martínez":23,
"Raniele":24,
"Ryan":25,
"Gabriel Moscardo":26,
"Maycon":27,
"Alex Santana":28,
"Paulinho":29,
"Charles":30,
"Breno Bidon":31,
"Igor Coronado":32,
"Matías Rojas":33,
"Rodrigo Garro":34,
"André Carrillo":35,
"Matheus Araújo":36,
"Talles Magno":37,
"Romero":38,
"Wesley":39,
"Gustavo Silva":40,
"Pedro Henrique":41,
"Biro":42,
"Kayke":43,
"Memphis Depay":44,
"Yuri Alberto":45,
"Pedro Raul":46,
"Héctor Hernandez":47,
"Giovane":48,
"Arthur Sousa":49,
"Yago":50,
"Luiz Eduardo":51,
"Jacaré":52,
"Bahia":53,
"Kauê":54,
"Lucas Veríssimo":55,
"Balbuena":56,
"Bruno Méndez":57,
"Gil":58,
"Murillo":59,
"Fábio Santos":60,
"Rafael Ramos":61,
"Cantillo":62,
"Roni":63,
"Renato Augusto":64,
"Du Queiroz":65,
"Ruan Oliveira":66,
"Giuliano":67,
"Pedrinho":68,
"Róger Guedes":69,
"Pedro":70,
"Adson":71,
"Chrystian Barletta":72,
"Júnior Moraes":73,
"Felipe Augusto":74,
"Ivan":75,
"Robson Bambu":76,
"João Victor":77,
"Bruno Melo":78,
"Robert Renan":79,
"Lucas Piton":80,
"João Pedro":81,
"Cantillo":82,
"Gabriel":83,
"Xavier":84,
"Ramiro":85,
"Luan":86,
"Mateus Vital":87,
"Willian":88,
"Léo Natel":89,
"Gabriel Pereira":90,
"Gustavo Mantuan":91,
"Jô":92,
"Jemerson":93,
"Léo Santos":94,
"Camacho":95,
"Mandaca":96,
"Juan Cazares":97,
"Ángelo Araos":98,
"Rómulo Otero":99,
"Marquinhos":100,
"Antony":101,
"Rodrigo Varanda":102,
"Cauê":103,
"Pedro Henrique":104,
"Marllon":105,
"Yago":106,
"Sidcley":107,
"Danilo Avelar":108,
"Carlos Augusto":109,
"Michel Macedo":110,
"Richard":111,
"Renê Júnior":112,
"Éderson":113,
"Everaldo":114,
"Jonathan Cafu":115,
"Pedrinho":116,
"Yony González":117,
"Janderson":118,
"Mauro Boselli":119,
"Vágner Love":120,
"Gustavo":121,
"Carlinhos":122,
"Matheus Davó":123,
"Vitinho":124,
"Walter":125,
"Madson":126,
"Fabrizio Angileri":127,
"Gol Contra":1000,
}

# %%
lista = [
12021,
12021,
12021,
12021,
12021,
32021,
32021,
32021,
52021,
62021,
62021,
72021,
72021,
72021,
82021,
132021,
132021,
142021,
142021,
152021,
162021,
162021,
162021,
172021,
182021,
192021,
202021,
212021,
222021,
222021,
242021,
242021,
262021,
262021,
272021,
272021,
272021,
282021,
282021,
292021,
292021,
292021,
292021,
322021,
322021,
322021,
322021,
322021,
332021,
332021,
332021,
332021,
362021,
382021,
392021,
412021,
412021,
422021,
442021,
452021,
472021,
482021,
482021,
492021,
512021,
512021,
512021,
522021,
532021,
542021,
552021,
562021,
572021,
572021,
582021,
582021,
592021,
592021,
592021,
612021,
632021,
632021,
642021,
652021,
672021,
672021,
672021,
692021,
692021,
702021,
712021,
722021,
]

# %%
lista = [
(192025,'Memphis Depay'),
]

lista_pegarID = []



for assistencia in lista:
    texto = (str(assistencia))
    texto = texto.replace('(','')
    texto = texto.replace(')','')
    texto = texto.replace("'",'')
    texto = texto.split(", ")
    nome_jogador = texto[1]
    id_jogo = texto[0]
    if nome_jogador in jogadores.keys():
        print(f"({id_jogo},'{jogadores[nome_jogador]}'),")
    elif nome_jogador == '':
        continue
    else:
        print(f"cadastrar jogador {nome_jogador}")
# Out:
# (192025,'44'),
