# %%
ficha = """
Ficha técnica de Palmeiras 0 x 1 Corinthians
Competição: Campeonato Paulista
Local: Allianz Parque, São Paulo, SP
Data: 16 de março de 2025 (domingo)
Horário: 18h30 (de Brasília)
Árbitro: Raphael Claus
Assistentes: Alex Ang Ribeiro e Fabrini Bevilaqua Costa
Árbitro de vídeo: José Claudio Rocha Filho
Gol: Yuri Alberto (Corinthians)
Cartões amarelos: Martínez e Abel Ferreira (Palmeiras); Fabrizio Angileri e Talles Magno (Corinthians)
Público: 40.992 pagantes (público total: 40.992)
Renda: R$ 5.717.077,40

PALMEIRAS: Weverton; Marcos Rocha (Mayke), Murilo, Micael e Piquerez; Richard Ríos (Flaco López), Martínez (Aníbal Moreno) e Raphael Veiga; Facundo Torres (Felipe Anderson), Estêvão e Vitor Roque.
Técnico: Abel Ferreira

CORINTHIANS: Hugo Souza; Matheuzinho, Félix Torres, Gustavo Henrique e Fabrizio Angileri; Raniele (Alex Santana), José Martínez (Ryan), André Carrillo (Breno Bidon) e Romero (Talles Magno); Memphis Depay e Yuri Alberto (Charles).
Técnico: Ramón Díaz"""

jogo = 19

ficha = ficha.split('\n')

# %%
#puxar a data
meses = {
    "janeiro": "01",
    "fevereiro": "02",
    "março": "03",
    "abril": "04",
    "maio": "05",
    "junho": "06",
    "julho": "07",
    "agosto": "08",
    "setembro": "09",
    "outubro": "10",
    "novembro": "11",
    "dezembro": "12"
}



for linha in ficha:
    if 'Data: ' in linha:
        linha = linha.split(' ')
        dia = linha[1]
        mes = linha[3]
        ano = linha[-2]
        
data = (f"{dia}/{meses[mes]}/{ano}")
print(data)
# Out:
# 16/03/2025

# %%
jogadores = {
"Hugo Souza":1,
"Matheus Donelli":2,
"Cássio":3,
"Carlos Miguel":4,
"Felipe Longo":5,
"Félix Torres":6,
"André Ramalho":7,
"Raul Gustavo":8,
"Gustavo Henrique":9,
"Caetano":10,
"Cacá":11,
"Renato Santos":12,
"Tchoca":13,
"Diego Palacios":14,
"Matheus Bidu":15,
"Hugo":16,
"Vitor Meer":17,
"Fagner":19,
"Léo Maná":20,
"Matheuzinho":21,
"Fausto":22,
"José Martínez":23,
"Raniele":24,
"Ryan":25,
"Gabriel Moscardo":26,
"Maycon":27,
"Alex Santana":28,
"Paulinho":29,
"Charles":30,
"Breno Bidon":31,
"Igor Coronado":32,
"Matías Rojas":33,
"Rodrigo Garro":34,
"André Carrillo":35,
"Matheus Araújo":36,
"Talles Magno":37,
"Romero":38,
"Wesley":39,
"Gustavo Silva":40,
"Pedro Henrique":41,
"Biro":42,
"Kayke":43,
"Memphis Depay":44,
"Yuri Alberto":45,
"Pedro Raul":46,
"Héctor Hernandez":47,
"Giovane":48,
"Arthur Sousa":49,
"Yago":50,
"Luiz Eduardo":51,
"Jacaré":52,
"Bahia":53,
"Kauê":54,
"Lucas Veríssimo":55,
"Balbuena":56,
"Bruno Méndez":57,
"Gil":58,
"Murillo":59,
"Fábio Santos":60,
"Rafael Ramos":61,
"Cantillo":62,
"Roni":63,
"Renato Augusto":64,
"Du Queiroz":65,
"Ruan Oliveira":66,
"Giuliano":67,
"Pedrinho":68,
"Róger Guedes":69,
"Pedro":70,
"Adson":71,
"Chrystian Barletta":72,
"Júnior Moraes":73,
"Felipe Augusto":74,
"Ivan":75,
"Robson Bambu":76,
"João Victor":77,
"Bruno Melo":78,
"Robert Renan":79,
"Lucas Piton":80,
"João Pedro":81,
"Cantillo":82,
"Gabriel":83,
"Xavier":84,
"Ramiro":85,
"Luan":86,
"Mateus Vital":87,
"Willian":88,
"Léo Natel":89,
"Gabriel Pereira":90,
"Gustavo Mantuan":91,
"Jô":92,
"Jemerson":93,
"Léo Santos":94,
"Camacho":95,
"Mandaca":96,
"Juan Cazares":97,
"Ángelo Araos":98,
"Rómulo Otero":99,
"Marquinhos":100,
"Antony":101,
"Rodrigo Varanda":102,
"Cauê":103,
"Pedro Henrique":104,
"Marllon":105,
"Yago":106,
"Sidcley":107,
"Danilo Avelar":108,
"Carlos Augusto":109,
"Michel Macedo":110,
"Richard":111,
"Renê Júnior":112,
"Éderson":113,
"Everaldo":114,
"Jonathan Cafu":115,
"Pedrinho":116,
"Yony González":117,
"Janderson":118,
"Mauro Boselli":119,
"Vágner Love":120,
"Gustavo":121,
"Carlinhos":122,
"Matheus Davó":123,
"Vitinho":124,
"Walter":125,
"Madson":126,
"Fabrizio Angileri":127,
"Gol Contra":1000,
}

# %%
#Cartão amarelo: Du Queiroz (Corinthians)

import re
lista_amarelo = []

for linha in ficha:
    try:
        jogador_amarelado = ''
        if 'Local: Neo Química Arena, São Paulo, SP' not in ficha:
            if 'amarelo' in linha:

                if ';' in linha:
                    busca = re.search(r';\s(.*)',linha)
                    if busca:
                        jogador_amarelado = busca.group(1) 
                else:
                    busca = re.search(r':\s(.*)()',linha)
                    if busca:
                        jogador_amarelado = busca.group(1) 
        else:
            if 'amarelo' in linha:
                if ';' in linha:
                    busca = re.search(r':\s(.*);',linha)
                    if busca:
                        jogador_amarelado = busca.group(1) 
                else:
                    busca = re.search(r':\s(.*)()',linha)
                    if busca:
                        jogador_amarelado = busca.group(1) 
        if jogador_amarelado:
            jogador_amarelado = jogador_amarelado.replace(' (Corinthians)','')
            jogador_amarelado = jogador_amarelado.replace(' e ',', ')
            jogador_amarelado = jogador_amarelado.split(', ')
            for jogador in jogador_amarelado:
                if jogador in jogadores:
                    lista_amarelo.append(jogador)
                elif jogador == 'Hugo Farias':
                    lista_amarelo.append('Hugo')
                elif jogador == 'João Pedro Tchoca':
                    lista_amarelo.append('Tchoca')
                elif jogador == 'Fausto Vera':
                    lista_amarelo.append('Fausto')
                elif jogador == 'Guilherme Biro':
                    lista_amarelo.append('Biro')  
                elif jogador == 'Otero':
                    lista_amarelo.append('Rómulo Otero')
                elif jogador == 'Cazares':
                    lista_amarelo.append('Juan Cazares')  
                else:
                    print(f"adicionar o {jogador} a lista")

            for i, jogador in enumerate(lista_amarelo):
                print(f"({jogo}{ano}, {jogadores[jogador]}),")
    except:
        print(f"Ocorreu um erro ao processar a linha: {linha}.")
        continue
# Out:
# (192025, 127),
# (192025, 37),

# %%
lista_vermelho = []


for linha in ficha:
    try:
        jogadores_expulsos = ''

        if 'Local: Neo Química Arena, São Paulo, SP' in ficha:
            if 'vermelho' in linha:
                if ';' in linha:
                    busca = re.search(r':\s(.*);',linha)
                    if busca:
                        jogadores_expulsos = busca.group(1)
                else:
                    busca = re.search(r':\s(.*)',linha)
                    jogadores_expulsos = busca.group(1)          
        else:
            if 'vermelho' in linha:
                if ';' in linha:
                    busca = re.search(r';\s(.*)',linha)
                    if busca:
                        jogadores_expulsos = busca.group(1)
                else:
                    busca = re.search(r':\s(.*)',linha)
                    jogadores_expulsos = busca.group(1)
        if jogadores_expulsos:
            jogadores_expulsos = jogadores_expulsos.replace(' (Corinthians)', '')
            jogadores_expulsos = jogadores_expulsos.replace(' e ', ', ')
            jogadores_expulsos = jogadores_expulsos.split(', ')

            for jogador in jogadores_expulsos:
                if jogador in jogadores:
                    lista_vermelho.append(jogador)
                else:
                    print(f"adicionar o {jogador} a lista")

            for i, jogador in enumerate(lista_vermelho):
                print(f"({jogo}{ano},{jogadores[jogador]})")
    except:
        print(f"Ocorreu um erro ao processar a linha: {linha}.")
        continue

# %%
#Gols: Igor Coronado, Talles Magno (Corinthians); Pedro Felipe (Noroeste)


lista_marcadores = []
for linha in ficha:
    if ' 0 x 0 ' in ficha:
        print('Jogo sem gols')
    else:
        if 'Local: Neo Química Arena, São Paulo, SP' not in ficha:
            if '(Corinthians)' in linha:
                if 'Gol' in linha:
                    if ';' in linha:
                        busca = re.search(r';\s(.*)',linha)
                        if busca:
                            marcadores = busca.group(1)
                    else:
                        busca = re.search(r':\s(.*)',linha)
                        if busca:
                            marcadores = busca.group(1)
                    marcadores = marcadores.replace(' (Corinthians)','')
                    marcadores = marcadores.replace(' e ',', ')
                    marcadores = marcadores.split(', ')
                    for jogador in marcadores:
                        lista_marcadores.append(jogador)
        else:
            if '(Corinthians)' in linha:
                if 'Gol' in linha:
                    if ';' in linha:
                        busca = re.search(r':\s(.*);',linha)
                        if busca:
                            marcadores = busca.group(1)
                    else:
                        busca = re.search(r':\s(.*)',linha)
                        if busca:
                            marcadores = busca.group(1)
                    marcadores = marcadores.replace(' (Corinthians)','')
                    marcadores = marcadores.replace(' e ',', ')
                    marcadores = marcadores.split(', ')
                    for jogador in marcadores:
                        lista_marcadores.append(jogador)

print("INSERT INTO gols_corinthians")
print("VALUES")
for jogador in lista_marcadores:
    if jogador in jogadores:
        print(f"({jogo}{ano},{jogadores[jogador]}),")
    elif jogador == 'João Pedro Tchoca':
        print(f"({jogo}{ano},{jogadores['Tchoca']}),")
    elif jogador == 'Cazares':
        print(f"({jogo}{ano},{jogadores['Juan Cazares']}),")   
    elif jogador == 'Vagner Love':
        print(f"({jogo}{ano},{jogadores['Vágner Love']}),")
    elif jogador == 'Gustavo Mosquito':
        print(f"({jogo}{ano},{jogadores['Gustavo Silva']}),")
    elif jogador == 'Otero':
        print(f"({jogo}{ano},{jogadores['Rómulo Otero']}),")
    elif jogador == 'Luis Mandaca':
        print(f"({jogo}{ano},{jogadores['Mandaca']}),")
    elif '(duas vezes)' in jogador:
        jogador = jogador.replace(' (duas vezes)','')
        print(f"({jogo}{ano},{jogadores[jogador]}),")
        print(f"({jogo}{ano},{jogadores[jogador]}),")
    elif '(três vezes)' in jogador:
        jogador = jogador.replace(' (três vezes)','')
        print(f"({jogo}{ano},{jogadores[jogador]}),")
        print(f"({jogo}{ano},{jogadores[jogador]}),")
        print(f"({jogo}{ano},{jogadores[jogador]}),")
    elif '(gol contra)' in jogador:
        print(f"({jogo}{ano},{jogadores['Gol Contra']}),")
    else:
        print(f"adicionar {jogador} a lista")
# Out:
# INSERT INTO gols_corinthians
# VALUES
# (192025,45),

# %%
#Gols: Lucas Evangelista (Red Bull Bragantino); Talles Magno, Pedro Raul (Corinthians)


lista_marcadores_adversario = []

for linha in ficha:
    if ' 0 x 0 ' in linha:
        print('Jogo sem gols')
        continue
    else:
        if 'Local: Neo Química Arena, São Paulo, SP' in ficha:
            if 'Gol' in linha:
                if '(Corinthians)' not in linha:
                    if 'Gol: ' in linha:
                        marcadores_adversarios = linha.replace('Gol: ','')
                    else:
                        marcadores_adversarios = linha.replace('Gols: ','')
                    marcadores_adversarios = marcadores_adversarios.replace(' e ',', ')
                    parentese = marcadores_adversarios.rfind('(')
                    marcadores_adversarios = marcadores_adversarios[:parentese]
                else:
                    marcadores_adversarios = linha.replace('Gols: ','')
                    pontovirgula = marcadores_adversarios.find(';')
                    marcadores_adversarios = marcadores_adversarios[pontovirgula+2:]
                    marcadores_adversarios = marcadores_adversarios.replace(' e ',', ')
                    parentese = marcadores_adversarios.rfind('(')
                    marcadores_adversarios = (marcadores_adversarios[:parentese])
        else:
            if 'Gol' in linha:
                if '(Corinthians)' not in linha:
                    if 'Gol: ' in linha:
                        marcadores_adversarios = linha.replace('Gol: ','')
                    else:
                        marcadores_adversarios = linha.replace('Gols: ','')
                    marcadores_adversarios = marcadores_adversarios.replace(' e ',', ')
                    parentese = marcadores_adversarios.rfind('(')
                    marcadores_adversarios = marcadores_adversarios[:parentese]
                else:
                    if 'Gol: ' in linha:
                        marcadores_adversarios = linha.replace('Gol: ','')
                    else:
                        marcadores_adversarios = linha.replace('Gols: ','')
                    marcadores_adversarios = marcadores_adversarios.replace(' e ',', ')
                    pontovirgula = marcadores_adversarios.find(';')
                    marcadores_adversarios = marcadores_adversarios[:pontovirgula+2]
                    parentese = marcadores_adversarios.rfind('(')
                    marcadores_adversarios = (marcadores_adversarios[:parentese])
        
print("INSERT INTO gols_adversario")
print("VALUES")
marcadores_adversarios = marcadores_adversarios.strip()
lista_marcadores_adversario = marcadores_adversarios.split(', ')
for jogador in lista_marcadores_adversario:
    if '(duas vezes)' in jogador:
        caractere = jogador.rfind('(')
        jogador = jogador[:caractere]
        jogador = jogador.strip()
        print(f"({jogo}{ano}, '{jogador}'),")
        print(f"({jogo}{ano}, '{jogador}'),")
    elif '(três vezes)' in jogador:
        caractere = jogador.rfind('(')
        jogador = jogador[:caractere]
        jogador = jogador.strip()
        print(f"({jogo}{ano}, '{jogador}'),")
        print(f"({jogo}{ano}, '{jogador}'),")
        print(f"({jogo}{ano}, '{jogador}'),")
    else:
        print(f"({jogo}{ano}, '{jogador}'),")
# Out:
# INSERT INTO gols_adversario
# VALUES
# (192025, ''),

# %%
lista_escalacao = []
dic_selecionados = {}

for linha in ficha:
    if 'CORINTHIANS: ' in linha:
        escalacao = linha.replace('CORINTHIANS: ','')
        escalacao = escalacao.replace(' (',', ')
        escalacao = escalacao.replace(')','')
        escalacao = escalacao.replace('; ',', ')
        escalacao = escalacao.replace(' e ',', ')
        escalacao = escalacao.replace('.','')
        escalacao = escalacao.strip()
        escalacao = escalacao.split(', ')
        dic_selecionados.update({jogo:escalacao})
for jogador in escalacao:
    if jogador in jogadores:
        lista_escalacao.append(jogadores[jogador])
    elif jogador == 'Matheus França':
        lista_escalacao.append(jogadores["Matheuzinho"])
    elif jogador == 'José Martínez':
        lista_escalacao.append(jogadores["José Martinez"])
    elif jogador == 'Hugo Farias':
        lista_escalacao.append(jogadores['Hugo'])
    elif jogador == 'Léo Mana':
        lista_escalacao.append(jogadores['Léo Maná']) 
    elif jogador == 'Gustavo Mosquito':
        lista_escalacao.append(jogadores['Gustavo Silva'])  
    elif jogador == 'João Pedro Tchoca':
        lista_escalacao.append(jogadores['Tchoca'])
    elif jogador == 'Héctor Hernández':
        lista_escalacao.append(jogadores['Héctor Hernandez'])
    elif jogador == 'Fausto Vera':
        lista_escalacao.append(jogadores['Fausto'])
    elif jogador == 'Guilherme Biro':
        lista_escalacao.append(jogadores['Biro'])    
    elif jogador == 'Wesley Gassova':
        lista_escalacao.append(jogadores['Wesley'])
    elif jogador == 'Cazares':
        lista_escalacao.append(jogadores['Juan Cazares'])  
    elif jogador == 'Vagner Love':
        lista_escalacao.append(jogadores['Vágner Love'])       
    elif jogador == 'Otero':
        lista_escalacao.append(jogadores['Rómulo Otero'])
    elif jogador == 'Luis Mandaca':
        lista_escalacao.append(jogadores['Mandaca'])
    else:
        print(f"adicionar {jogador} a lista de jogadores\n") 

print(f"INSERT INTO escalacoes\nVALUES")    
for i in lista_escalacao:
    print(f"({jogo}{ano},{i}),")
# Out:
# INSERT INTO escalacoes
# VALUES
# (192025,1),
# (192025,21),
# (192025,6),
# (192025,9),
# (192025,127),
# (192025,24),
# (192025,28),
# (192025,23),
# (192025,25),
# (192025,35),
# (192025,31),
# (192025,38),
# (192025,37),
# (192025,44),
# (192025,45),
# (192025,30),
